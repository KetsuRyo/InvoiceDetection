# %%
ls
# Out:
# benchmark/  __init__.py   ppocr/            README.md         tools/
# configs/    LICENSE       PPOCRLabel/       requirements.txt  train_data/
# deploy/     MANIFEST.in   ppstructure/      setup.py          train.sh
# doc/        output/       pretrain_models/  StyleText/        Untitled.ipynb
# inference/  paddleocr.py  README_ch.md      test_tipc/

# %%
sudo cp cuda/include/cudnn.h /usr/local/cuda/include/
sudo cp cuda/lib64/libcudnn* /usr/local/cuda/lib64/

# %%
# !python3 tools/train.py -c configs/rec/rec_jl_train.yml -o Global.pretrained_model=./pretrain_models/best_accuracy
# Out:
# [2022/03/11 14:22:17] root INFO: Architecture :
# [2022/03/11 14:22:17] root INFO:     Backbone :
# [2022/03/11 14:22:17] root INFO:         layers : 34
# [2022/03/11 14:22:17] root INFO:         name : ResNet
# [2022/03/11 14:22:17] root INFO:     Head :
# [2022/03/11 14:22:17] root INFO:         fc_decay : 4e-05
# [2022/03/11 14:22:17] root INFO:         name : CTCHead
# [2022/03/11 14:22:17] root INFO:     Neck :
# [2022/03/11 14:22:17] root INFO:         encoder_type : rnn
# [2022/03/11 14:22:17] root INFO:         hidden_size : 256
# [2022/03/11 14:22:17] root INFO:         name : SequenceEncoder
# [2022/03/11 14:22:17] root INFO:     Transform : None
# [2022/03/11 14:22:17] root INFO:     algorithm : CRNN
# [2022/03/11 14:22:17] root INFO:     model_type : rec
# [2022/03/11 14:22:17] root INFO: Eval :
# [2022/03/11 14:22:17] root INFO:     dataset :
# [2022/03/11 14:22:17] root INFO:         data_dir : ./train_data/rec/test/
# ...

# %%
# !python3 tools/export_model.py -c configs/rec/rec_jl_train.yml -o Global.pretrained_model=./output/rec/20220308/latest  Global.save_inference_dir=./inference/rec_crnn08/
# Out:
# W0309 09:04:47.594508 408933 device_context.cc:447] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 11.4, Runtime API Version: 10.2
# W0309 09:04:47.600634 408933 device_context.cc:465] device: 0, cuDNN Version: 8.2.
# [2022/03/09 09:04:49] root INFO: load pretrain successful from ./output/rec/20220308/latest
# [2022/03/09 09:04:50] root INFO: inference model is saved to ./inference/rec_crnn08/inference
